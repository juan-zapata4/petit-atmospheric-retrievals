# %%
import os
os.environ["OMP_NUM_THREADS"] = "8"

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import petitRADTRANS as prt
from petitRADTRANS.retrieval.models import guillot_transmission
from petitRADTRANS import physical_constants as cst
from petitRADTRANS.retrieval import Retrieval,RetrievalConfig
from petitRADTRANS.retrieval.models import Planet
from petitRADTRANS.retrieval.utils import log_prior
from matplotlib.patches import Rectangle
from petitRADTRANS.plotlib import plot_radtrans_opacities

from petitRADTRANS.retrieval.models import (
    isothermal_transmission,
    guillot_transmission,
    guillot_patchy_transmission,
    madhu_seager_patchy_transmission
)
from petitRADTRANS.retrieval.parameter import Parameter
from petitRADTRANS.plotlib.style import set_petitradtrans_plot_style

set_petitradtrans_plot_style()
# Out:
# Using pRT Plotting style!

# %%
planet = Planet.get("K2-18 b")
root_path = os.path.abspath(os.path.join(os.getcwd(), "../../"))

retrieval_config = RetrievalConfig(retrieval_name="K2-18b_guillot_clear_standard",
                                run_mode="retrieve",
                                pressures=np.logspace(-6, 2, 120))

retrieval_config.add_data(
    "K2-18b_NIRISS",
    os.path.join(root_path, "spectra/K2-18b_NIRISS.txt"),
    data_resolution=700,
    model_resolution=1500,
    model_generating_function=guillot_transmission,
    line_opacity_mode="c-k",
)

retrieval_config.add_data(
    "K2-18b_NIRSPEC",
    os.path.join(root_path, "spectra/K2-18b_NIRSPEC.txt"),
    data_resolution=2700,
    model_resolution=1500,
    model_generating_function=guillot_transmission,
    line_opacity_mode="c-k"
)

retrieval_config.add_parameter('D_pl', False, value=planet.system_distance)
retrieval_config.add_parameter('stellar_radius', False, value=planet.star_radius)
retrieval_config.add_parameter('planet_radius', False, value = planet.radius)
retrieval_config.add_parameter('mass', False, value = planet.mass)

retrieval_config.add_parameter('T_int', True, transform_prior_cube_coordinate = lambda x : 600*x)
retrieval_config.add_parameter('T_equ', True, transform_prior_cube_coordinate = lambda x : 600*x)
retrieval_config.add_parameter('gamma', True, transform_prior_cube_coordinate = lambda x : -2+8*x)
retrieval_config.add_parameter('log_kappa_IR', True, transform_prior_cube_coordinate = lambda x : -3+4*x)

retrieval_config.set_rayleigh_species(['H2', 'He'])
retrieval_config.set_continuum_opacities(["H2-H2","H2-He"])
retrieval_config.set_line_species(['CH4', 'CO2', 'H2O', 'NH3'], eq=False, abund_lim = (-8.0,-0.1))

retrieval_config.parameters['T_int'].plot_in_corner = True
retrieval_config.parameters['T_int'].corner_ranges = (0,600)
retrieval_config.parameters['T_equ'].plot_in_corner = True
retrieval_config.parameters['T_equ'].corner_ranges = (0,600)
retrieval_config.parameters['gamma'].plot_in_corner = True
retrieval_config.parameters['gamma'].corner_ranges = (-2,6)
retrieval_config.parameters['log_kappa_IR'].plot_in_corner = True
retrieval_config.parameters['log_kappa_IR'].corner_ranges = (-3,1)

for spec in retrieval_config.line_species:
    retrieval_config.parameters[spec].plot_in_corner = True
    retrieval_config.parameters[spec].corner_ranges = (-8.2,0.2)

retrieval_config.plot_kwargs["spec_xlabel"] = 'Wavelength [micron]'
retrieval_config.plot_kwargs["spec_ylabel"] = r'$(R_{\rm P}/R_*)^2$ [ppm]'
retrieval_config.plot_kwargs["y_axis_scaling"] = 1e6 # so we have units of ppm
retrieval_config.plot_kwargs["xscale"] = 'linear'
retrieval_config.plot_kwargs["yscale"] = 'linear'

# Use at least ~100 samples to plot 3 sigma curves
retrieval_config.plot_kwargs["nsample"] = 100

retrieval_config.plot_kwargs["take_PTs_from"] = "K2-18b_NIRSPEC"
retrieval_config.plot_kwargs["temp_limits"] = [100, 800]
retrieval_config.plot_kwargs["press_limits"] = [1e-6, 1e2]

output_directory = os.path.join(root_path, "outputs")
retrieval = Retrieval(retrieval_config,
                      output_directory=output_directory,
                      evaluate_sample_spectra=False,
                      use_prt_plot_style=True)

retrieval.run(n_live_points=200,
              const_efficiency_mode=False,
              resume=False,
              error_checking=False)
# Out:
# Setting up Radtrans object for data 'K2-18b_NIRISS'...
# Loading Radtrans opacities...
#  Loading line opacities of species 'CH4.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CH4/12C-1H4/12C-1H4__YT34to10.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'CO2.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CO2/12C-16O2/12C-16O2__UCL-4000.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'H2O.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/H2O/1H2-16O/1H2-16O__POKAZATEL.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'NH3.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/NH3/14N-1H3/14N-1H3__CoYuTe.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Successfully loaded all line opacities
#  Loading CIA opacities for H2-H2 from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--H2/H2--H2-NatAbund/H2--H2-NatAbund__BoRi.R831_0.6-250mu.ciatable.petitRADTRANS.h5'... Done.
#  Loading CIA opacities for H2-He from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--He/H2--He-NatAbund/H2--He-NatAbund__BoRi.DeltaWavenumber2_0.5-500mu.ciatable.petitRADTRANS.h5'... Done.
#  Successfully loaded all CIA opacities
# Successfully loaded all opacities
# Setting up Radtrans object for data 'K2-18b_NIRSPEC'...
# Loading Radtrans opacities...
#  Loading line opacities of species 'CH4.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CH4/12C-1H4/12C-1H4__YT34to10.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'CO2.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CO2/12C-16O2/12C-16O2__UCL-4000.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'H2O.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/H2O/1H2-16O/1H2-16O__POKAZATEL.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'NH3.R1500' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/NH3/14N-1H3/14N-1H3__CoYuTe.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Successfully loaded all line opacities
#  Loading CIA opacities for H2-H2 from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--H2/H2--H2-NatAbund/H2--H2-NatAbund__BoRi.R831_0.6-250mu.ciatable.petitRADTRANS.h5'... Done.
#  Loading CIA opacities for H2-He from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--He/H2--He-NatAbund/H2--He-NatAbund__BoRi.DeltaWavenumber2_0.5-500mu.ciatable.petitRADTRANS.h5'... Done.
#  Successfully loaded all CIA opacities
# Successfully loaded all opacities
# Starting retrieval K2-18b_guillot_clear_standard
# Error checking is turned off!! You might overwrite your retrieval output files!
# Starting retrieval: K2-18b_guillot_clear_standard
#
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    8
#  *****************************************************
#  Starting MultiNest
#  generating live points
# /home/juan/retrievals/petit/lib/python3.10/site-packages/petitRADTRANS/physics.py:532: RuntimeWarning: overflow encountered in exp
#   + (gamma / 3. ** 0.5 - 1. / 3. ** 0.5 / gamma) * np.exp(-gamma * tau * 3. ** 0.5)
# /home/juan/retrievals/petit/lib/python3.10/site-packages/petitRADTRANS/physics.py:528: RuntimeWarning: overflow encountered in multiply
#   + 0.75 * t_irr ** 4. * redistribution_coefficient
# /home/juan/retrievals/petit/lib/python3.10/site-packages/petitRADTRANS/physics.py:526: RuntimeWarning: invalid value encountered in power
#   temperature = (
# /home/juan/retrievals/petit/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py:482: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# Abundance sum > 1.0, msum=1.2604497539599009
# Abundance sum > 1.0, msum=1.5752293384506602
# Abundance sum > 1.0, msum=1.218576509855332
#  live points generated, starting sampling
# Abundance sum > 1.0, msum=1.1821443354688814
# Acceptance Rate:                        0.939850
# Replacements:                                250
# Total Samples:                               266
# Nested Sampling ln(Z):            -694573.779759
# Importance Nested Sampling ln(Z):   28777.012330 +/-  0.998118
# Abundance sum > 1.0, msum=1.0371117640051175
# Acceptance Rate:                        0.892857
# Replacements:                                300
# Total Samples:                               336
# Nested Sampling ln(Z):              13863.405088
# Importance Nested Sampling ln(Z):   28776.778715 +/-  0.998511
# Acceptance Rate:                        0.819672
# Replacements:                                350
# Total Samples:                               427
# Nested Sampling ln(Z):              20823.426255
# Importance Nested Sampling ln(Z):   28776.539042 +/-  0.998828
# Abundance sum > 1.0, msum=1.0198847861875953
# Acceptance Rate:                        0.763359
# Replacements:                                400
# Total Samples:                               524
# Nested Sampling ln(Z):              23348.304896
# Importance Nested Sampling ln(Z):   28797.169208 +/-  0.999045
# Acceptance Rate:                        0.746269
# Replacements:                                450
# Total Samples:                               603
# Nested Sampling ln(Z):              25416.739014
# Importance Nested Sampling ln(Z):   28796.235025 +/-  0.999137
# Acceptance Rate:                        0.719424
# Replacements:                                500
# Total Samples:                               695
# Nested Sampling ln(Z):              26777.773591
# Importance Nested Sampling ln(Z):   28795.777307 +/-  0.999246
# Acceptance Rate:                        0.680693
# Replacements:                                550
# Total Samples:                               808
# Nested Sampling ln(Z):              27505.416528
# Importance Nested Sampling ln(Z):   28795.220391 +/-  0.999347
# Acceptance Rate:                        0.642398
# Replacements:                                600
# Total Samples:                               934
# Nested Sampling ln(Z):              27958.054646
# Importance Nested Sampling ln(Z):   28794.840626 +/-  0.999431
# Acceptance Rate:                        0.615530
# Replacements:                                650
# Total Samples:                              1056
# Nested Sampling ln(Z):              28264.773466
# Importance Nested Sampling ln(Z):   28794.474858 +/-  0.999493
# Acceptance Rate:                        0.581395
# Replacements:                                700
# Total Samples:                              1204
# Nested Sampling ln(Z):              28387.028538
# Importance Nested Sampling ln(Z):   28794.137975 +/-  0.999551
# Acceptance Rate:                        0.560119
# Replacements:                                750
# Total Samples:                              1339
# Nested Sampling ln(Z):              28468.864404
# Importance Nested Sampling ln(Z):   28802.793303 +/-  0.999279
# Abundance sum > 1.0, msum=1.19078343274614
# Acceptance Rate:                        0.514469
# Replacements:                                800
# Total Samples:                              1555
# Nested Sampling ln(Z):              28524.517142
# Importance Nested Sampling ln(Z):   28802.460524 +/-  0.999331
# Abundance sum > 1.0, msum=1.0331870630509739
# Acceptance Rate:                        0.490479
# Replacements:                                850
# Total Samples:                              1733
# Nested Sampling ln(Z):              28594.550258
# Importance Nested Sampling ln(Z):   28802.216330 +/-  0.999364
# Abundance sum > 1.0, msum=1.0584268203961986
# Acceptance Rate:                        0.460358
# Replacements:                                900
# Total Samples:                              1955
# Nested Sampling ln(Z):              28619.384115
# Importance Nested Sampling ln(Z):   28801.861445 +/-  0.999396
# Acceptance Rate:                        0.433197
# Replacements:                                950
# Total Samples:                              2193
# Nested Sampling ln(Z):              28644.394259
# Importance Nested Sampling ln(Z):   28801.520001 +/-  0.999424
# Acceptance Rate:                        0.419463
# Replacements:                               1000
# Total Samples:                              2384
# Nested Sampling ln(Z):              28666.518930
# Importance Nested Sampling ln(Z):   28801.238622 +/-  0.999442
# Acceptance Rate:                        0.400458
# Replacements:                               1050
# Total Samples:                              2622
# Nested Sampling ln(Z):              28687.519111
# Importance Nested Sampling ln(Z):   28800.956855 +/-  0.999457
# Acceptance Rate:                        0.379965
# Replacements:                               1100
# Total Samples:                              2895
# Nested Sampling ln(Z):              28703.613266
# Importance Nested Sampling ln(Z):   28801.201608 +/-  0.655596
# Acceptance Rate:                        0.359937
# Replacements:                               1150
# Total Samples:                              3195
# Nested Sampling ln(Z):              28714.651336
# Importance Nested Sampling ln(Z):   28806.386360 +/-  0.995626
# Acceptance Rate:                        0.349548
# Replacements:                               1200
# Total Samples:                              3433
# Nested Sampling ln(Z):              28725.764657
# Importance Nested Sampling ln(Z):   28806.172761 +/-  0.995633
# Acceptance Rate:                        0.336474
# Replacements:                               1250
# Total Samples:                              3715
# Nested Sampling ln(Z):              28735.063639
# Importance Nested Sampling ln(Z):   28805.953694 +/-  0.995641
# Acceptance Rate:                        0.328947
# Replacements:                               1300
# Total Samples:                              3952
# Nested Sampling ln(Z):              28744.820697
# Importance Nested Sampling ln(Z):   28805.776775 +/-  0.962237
# Acceptance Rate:                        0.314979
# Replacements:                               1350
# Total Samples:                              4286
# Nested Sampling ln(Z):              28752.232869
# Importance Nested Sampling ln(Z):   28805.459244 +/-  0.962224
# Acceptance Rate:                        0.305877
# Replacements:                               1400
# Total Samples:                              4577
# Nested Sampling ln(Z):              28760.020015
# Importance Nested Sampling ln(Z):   28805.214486 +/-  0.960767
# Acceptance Rate:                        0.297802
# Replacements:                               1450
# Total Samples:                              4869
# Nested Sampling ln(Z):              28766.266198
# Importance Nested Sampling ln(Z):   28805.022620 +/-  0.904485
# Abundance sum > 1.0, msum=1.1380016695114321
# /home/juan/retrievals/petit/lib/python3.10/site-packages/petitRADTRANS/physics.py:532: RuntimeWarning: overflow encountered in multiply
#   + (gamma / 3. ** 0.5 - 1. / 3. ** 0.5 / gamma) * np.exp(-gamma * tau * 3. ** 0.5)
# Acceptance Rate:                        0.294349
# Replacements:                               1500
# Total Samples:                              5096
# Nested Sampling ln(Z):              28771.998373
# Importance Nested Sampling ln(Z):   28807.996702 +/-  0.893468
# Acceptance Rate:                        0.291627
# Replacements:                               1550
# Total Samples:                              5315
# Nested Sampling ln(Z):              28777.972935
# Importance Nested Sampling ln(Z):   28807.775371 +/-  0.891850
# Abundance sum > 1.0, msum=1.2926634079041825
# Acceptance Rate:                        0.281393
# Replacements:                               1600
# Total Samples:                              5686
# Nested Sampling ln(Z):              28782.253292
# Importance Nested Sampling ln(Z):   28809.197961 +/-  0.838358
# Abundance sum > 1.0, msum=1.154611784384438
# Acceptance Rate:                        0.271337
# Replacements:                               1650
# Total Samples:                              6081
# Nested Sampling ln(Z):              28785.844902
# Importance Nested Sampling ln(Z):   28808.906708 +/-  0.837113
# Acceptance Rate:                        0.266291
# Replacements:                               1700
# Total Samples:                              6384
# Nested Sampling ln(Z):              28789.037932
# Importance Nested Sampling ln(Z):   28809.286327 +/-  0.601412
# Abundance sum > 1.0, msum=1.02686757682523
# Acceptance Rate:                        0.258723
# Replacements:                               1750
# Total Samples:                              6764
# Nested Sampling ln(Z):              28791.652153
# Importance Nested Sampling ln(Z):   28809.009693 +/-  0.572459
# Acceptance Rate:                        0.251924
# Replacements:                               1800
# Total Samples:                              7145
# Nested Sampling ln(Z):              28794.176708
# Importance Nested Sampling ln(Z):   28808.916333 +/-  0.488684
# Acceptance Rate:                        0.244580
# Replacements:                               1850
# Total Samples:                              7564
# Nested Sampling ln(Z):              28796.096188
# Importance Nested Sampling ln(Z):   28808.918279 +/-  0.399184
# Acceptance Rate:                        0.238484
# Replacements:                               1900
# Total Samples:                              7967
# Nested Sampling ln(Z):              28797.698039
# Importance Nested Sampling ln(Z):   28808.727851 +/-  0.374312
# Acceptance Rate:                        0.231757
# Replacements:                               1950
# Total Samples:                              8414
# Nested Sampling ln(Z):              28799.393319
# Importance Nested Sampling ln(Z):   28808.605745 +/-  0.345081
# Acceptance Rate:                        0.229437
# Replacements:                               2000
# Total Samples:                              8717
# Nested Sampling ln(Z):              28800.892904
# Importance Nested Sampling ln(Z):   28808.608106 +/-  0.294446
# Acceptance Rate:                        0.226294
# Replacements:                               2050
# Total Samples:                              9059
# Nested Sampling ln(Z):              28802.316896
# Importance Nested Sampling ln(Z):   28808.895135 +/-  0.317758
# Acceptance Rate:                        0.221776
# Replacements:                               2100
# Total Samples:                              9469
# Nested Sampling ln(Z):              28803.510488
# Importance Nested Sampling ln(Z):   28808.929384 +/-  0.255882
# Acceptance Rate:                        0.218208
# Replacements:                               2150
# Total Samples:                              9853
# Nested Sampling ln(Z):              28804.522235
# Importance Nested Sampling ln(Z):   28809.102632 +/-  0.213922
# Acceptance Rate:                        0.215898
# Replacements:                               2200
# Total Samples:                             10190
# Nested Sampling ln(Z):              28805.449516
# Importance Nested Sampling ln(Z):   28809.086041 +/-  0.186999
# Acceptance Rate:                        0.213797
# Replacements:                               2250
# Total Samples:                             10524
# Nested Sampling ln(Z):              28806.388123
# Importance Nested Sampling ln(Z):   28809.266894 +/-  0.170856
# Acceptance Rate:                        0.210257
# Replacements:                               2300
# Total Samples:                             10939
# Nested Sampling ln(Z):              28807.181322
# Importance Nested Sampling ln(Z):   28809.549639 +/-  0.181905
# Abundance sum > 1.0, msum=1.0041465397627376
# Acceptance Rate:                        0.206721
# Replacements:                               2350
# Total Samples:                             11368
# Nested Sampling ln(Z):              28807.819944
# Importance Nested Sampling ln(Z):   28809.655221 +/-  0.174612
# Acceptance Rate:                        0.205761
# Replacements:                               2400
# Total Samples:                             11664
# Nested Sampling ln(Z):              28808.359019
# Importance Nested Sampling ln(Z):   28809.635021 +/-  0.152223
# Acceptance Rate:                        0.204678
# Replacements:                               2450
# Total Samples:                             11970
# Nested Sampling ln(Z):              28808.829743
# Importance Nested Sampling ln(Z):   28809.887714 +/-  0.165888
# Acceptance Rate:                        0.201483
# Replacements:                               2500
# Total Samples:                             12408
# Nested Sampling ln(Z):              28809.296444
# Importance Nested Sampling ln(Z):   28809.897443 +/-  0.132713
# Acceptance Rate:                        0.198012
# Replacements:                               2550
# Total Samples:                             12878
# Nested Sampling ln(Z):              28809.724022
# Importance Nested Sampling ln(Z):   28809.944712 +/-  0.119276
# Acceptance Rate:                        0.196464
# Replacements:                               2600
# Total Samples:                             13234
# Nested Sampling ln(Z):              28810.107541
# Importance Nested Sampling ln(Z):   28810.032322 +/-  0.123576
# Acceptance Rate:                        0.195312
# Replacements:                               2650
# Total Samples:                             13568
# Nested Sampling ln(Z):              28810.445677
# Importance Nested Sampling ln(Z):   28810.109172 +/-  0.109205
# Acceptance Rate:                        0.193175
# Replacements:                               2700
# Total Samples:                             13977
# Nested Sampling ln(Z):              28810.738726
# Importance Nested Sampling ln(Z):   28810.095347 +/-  0.095451
# Acceptance Rate:                        0.190893
# Replacements:                               2750
# Total Samples:                             14406
# Nested Sampling ln(Z):              28810.984099
# Importance Nested Sampling ln(Z):   28810.175027 +/-  0.098460
# Acceptance Rate:                        0.190217
# Replacements:                               2800
# Total Samples:                             14720
# Nested Sampling ln(Z):              28811.184908
# Importance Nested Sampling ln(Z):   28810.245069 +/-  0.083602
# Acceptance Rate:                        0.187772
# Replacements:                               2850
# Total Samples:                             15178
# Nested Sampling ln(Z):              28811.365421
# Importance Nested Sampling ln(Z):   28810.214248 +/-  0.070393
# Acceptance Rate:                        0.186747
# Replacements:                               2900
# Total Samples:                             15529
# Nested Sampling ln(Z):              28811.536000
# Importance Nested Sampling ln(Z):   28810.285597 +/-  0.062332
# Acceptance Rate:                        0.186026
# Replacements:                               2950
# Total Samples:                             15858
# Nested Sampling ln(Z):              28811.686435
# Importance Nested Sampling ln(Z):   28810.355214 +/-  0.058248
# Acceptance Rate:                        0.184253
# Replacements:                               3000
# Total Samples:                             16282
# Nested Sampling ln(Z):              28811.821821
# Importance Nested Sampling ln(Z):   28810.380192 +/-  0.051460
# Acceptance Rate:                        0.184401
# Replacements:                               3050
# Total Samples:                             16540
# Nested Sampling ln(Z):              28811.945018
# Importance Nested Sampling ln(Z):   28810.421999 +/-  0.047615
# Acceptance Rate:                        0.183889
# Replacements:                               3100
# Total Samples:                             16858
# Nested Sampling ln(Z):              28812.055438
# Importance Nested Sampling ln(Z):   28810.441424 +/-  0.044177
# Abundance sum > 1.0, msum=1.1624022943445167
# Acceptance Rate:                        0.183225
# Replacements:                               3150
# Total Samples:                             17192
# Nested Sampling ln(Z):              28812.153873
# Importance Nested Sampling ln(Z):   28810.456143 +/-  0.040608
# Acceptance Rate:                        0.182503
# Replacements:                               3200
# Total Samples:                             17534
# Nested Sampling ln(Z):              28812.240361
# Importance Nested Sampling ln(Z):   28810.493189 +/-  0.037848
# Acceptance Rate:                        0.181240
# Replacements:                               3250
# Total Samples:                             17932
# Nested Sampling ln(Z):              28812.318022
# Importance Nested Sampling ln(Z):   28810.512835 +/-  0.035491
# Acceptance Rate:                        0.181199
# Replacements:                               3300
# Total Samples:                             18212
# Nested Sampling ln(Z):              28812.385794
# Importance Nested Sampling ln(Z):   28810.549832 +/-  0.034029
# Acceptance Rate:                        0.181228
# Replacements:                               3350
# Total Samples:                             18485
# Nested Sampling ln(Z):              28812.443465
# Importance Nested Sampling ln(Z):   28810.586482 +/-  0.032442
# Acceptance Rate:                        0.180458
# Replacements:                               3400
# Total Samples:                             18841
# Nested Sampling ln(Z):              28812.494644
# Importance Nested Sampling ln(Z):   28810.606040 +/-  0.030897
# Acceptance Rate:                        0.180713
# Replacements:                               3450
# Total Samples:                             19091
# Nested Sampling ln(Z):              28812.537673
# Importance Nested Sampling ln(Z):   28810.632351 +/-  0.029761
# Acceptance Rate:                        0.180761
# Replacements:                               3467
# Total Samples:                             19180
# Nested Sampling ln(Z):              28812.550618
# Importance Nested Sampling ln(Z):   28810.638609 +/-  0.029433
#  ln(ev)=   28812.763168199472      +/-  0.25106065167097058
#   analysing data from /home/juan/retrievals/tesis/outputs/out_PMN/K2-18b_guillot_clear_standard_.txt
#  Total Likelihood Evaluations:        19180
#  Sampling finished. Exiting MultiNest
#   marginal likelihood:
#     ln Z = 28810.6 +- 0.0
#   parameters:
#     T_int          144 +- 31
#     T_equ          64 +- 40
#     gamma          3.3 +- 1.8
#     log_kappa_IR   0.42 +- 0.30
#     CH4            -0.92 +- 0.19
#     CO2            -1.22 +- 0.39
#     H2O            -5.4 +- 1.9
#     NH3            -6.2 +- 1.2

# %%
sample_dict, parameter_dict = retrieval.get_samples(output_directory=output_directory)
samples_use = sample_dict[retrieval.configuration.retrieval_name]
parameters_read = parameter_dict[retrieval.configuration.retrieval_name]


fig,ax,ax_r = retrieval.plot_spectra(samples_use, parameters_read, refresh = True, mode = 'bestfit')
ax.set_ylim(2750, 3150)
plt.show()
# Out:
# Not in evaluate mode. Changing run mode to evaluate.
#
# Plotting Best-fit spectrum
# Best fit likelihood = 28828.18
# T_int 162.47351749218595
# T_equ 28.471480797558417
# gamma 3.410330086886483
# log_kappa_IR 0.44749466655683134
# CH4 -0.7619329447460252
# CO2 -0.8229006014562099
# H2O -7.059455950092552
# NH3 -7.091694022699958
# Loading Radtrans opacities...
#  Loading line opacities of species 'CH4' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CH4/12C-1H4/12C-1H4__YT34to10.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'CO2' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CO2/12C-16O2/12C-16O2__UCL-4000.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'H2O' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/H2O/1H2-16O/1H2-16O__POKAZATEL.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'NH3' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/NH3/14N-1H3/14N-1H3__CoYuTe.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Successfully loaded all line opacities
#  Loading CIA opacities for H2-H2 from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--H2/H2--H2-NatAbund/H2--H2-NatAbund__BoRi.R831_0.6-250mu.ciatable.petitRADTRANS.h5'... Done.
#  Loading CIA opacities for H2-He from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--He/H2--He-NatAbund/H2--He-NatAbund__BoRi.DeltaWavenumber2_0.5-500mu.ciatable.petitRADTRANS.h5'... Done.
#  Successfully loaded all CIA opacities
# Successfully loaded all opacities
# Best fit 𝛘^2 = 4782.84
# Best fit 𝛘^2/DoF = 1.09
# /home/juan/retrievals/petit/lib/python3.10/site-packages/petitRADTRANS/retrieval/retrieval.py:4413: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
fig, ax = retrieval.plot_pt(sample_dict,parameters_read, contribution=False)
ax.axhline(y=0.986923, linestyle="--", color="k", linewidth=1, alpha=0.4)
ax.invert_yaxis()
plt.show()
# Out:
# Plotting PT profiles

# %%
retrieval.plot_corner(sample_dict, parameter_dict, parameters_read, title_kwargs= {"fontsize" : 10})
plt.show()
# Out:
# Making corner plot

# %%
parameters = {
    'stellar_radius': Parameter('stellar_radius', False, value= planet.star_radius),
    'planet_radius': Parameter('planet_radius', False, value= 0.211*cst.r_jup),
    'mass': Parameter('mass', False, value= 0.02807*cst.m_jup),
    'T_int': Parameter('T_int', False, value= retrieval.best_fit_parameters['T_int'].value),
    'T_equ': Parameter('T_equ', False, value= retrieval.best_fit_parameters['T_equ'].value),
    'gamma': Parameter('gamma', False, value= retrieval.best_fit_parameters['gamma'].value),
    'log_kappa_IR': Parameter('log_kappa_IR', False, value= retrieval.best_fit_parameters['log_kappa_IR'].value),
    'CH4': Parameter('CH4', False, value= retrieval.best_fit_parameters['CH4'].value),
    'CO2': Parameter('CO2', False, value= retrieval.best_fit_parameters['CO2'].value),
    'H2O': Parameter('H2O', False, value= retrieval.best_fit_parameters['H2O'].value),
    'NH3': Parameter('NH3', False, value= retrieval.best_fit_parameters['NH3'].value),
}

line_species = [
    'CH4',
    'CO2',
    'H2O',
    'NH3'
]

rayleigh_species = ['H2', 'He']
continuum_opacities = ['H2-H2', 'H2-He']
cloud_species = []
pressures = np.logspace(-6,2,100)
wls = np.concatenate([retrieval_config.data['K2-18b_NIRISS'].wavelengths, retrieval_config.data['K2-18b_NIRSPEC'].wavelengths])

atmosphere = prt.radtrans.Radtrans(
    pressures=pressures,
    line_species=line_species,
    rayleigh_species=rayleigh_species,
    gas_continuum_contributors=continuum_opacities,
    cloud_species=cloud_species,
    wavelength_boundaries=[wls[0], wls[-1]]
)

wavelength, model = guillot_transmission(atmosphere, parameters, amr = False, pt_plot_mode = False)
pressure,temperature = guillot_transmission(atmosphere, parameters, amr = False, pt_plot_mode = True)
# Out:
# Loading Radtrans opacities...
#  Loading line opacities of species 'CH4' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CH4/12C-1H4/12C-1H4__YT34to10.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'CO2' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CO2/12C-16O2/12C-16O2__UCL-4000.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'H2O' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/H2O/1H2-16O/1H2-16O__POKAZATEL.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'NH3' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/NH3/14N-1H3/14N-1H3__CoYuTe.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Successfully loaded all line opacities
#  Loading CIA opacities for H2-H2 from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--H2/H2--H2-NatAbund/H2--H2-NatAbund__BoRi.R831_0.6-250mu.ciatable.petitRADTRANS.h5'... Done.
#  Loading CIA opacities for H2-He from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--He/H2--He-NatAbund/H2--He-NatAbund__BoRi.DeltaWavenumber2_0.5-500mu.ciatable.petitRADTRANS.h5'... Done.
#  Successfully loaded all CIA opacities
# Successfully loaded all opacities

# %%
fig, ax = plt.subplots()
ax.plot(temperature, pressure, linewidth = 2)
ax.set_xlabel("Temperature [K]")
ax.set_ylabel(r"Pressure [bar]")
ax.set_ylim(1e2,1e-6)
ax.set_xlim(100, 700)
ax.set_yscale('log')
ax.grid(alpha=0.2)
plt.show()

# %%
retrieval.plot_contribution(samples_use, parameters_read)
plt.show()
# Out:
# Plotting Best-fit contribution function
# Best fit likelihood = 28832.05
# Loading Radtrans opacities...
#  Loading line opacities of species 'CH4' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CH4/12C-1H4/12C-1H4__YT34to10.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'CO2' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CO2/12C-16O2/12C-16O2__UCL-4000.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'H2O' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/H2O/1H2-16O/1H2-16O__POKAZATEL.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'NH3' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/NH3/14N-1H3/14N-1H3__CoYuTe.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Successfully loaded all line opacities
#  Loading CIA opacities for H2-H2 from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--H2/H2--H2-NatAbund/H2--H2-NatAbund__BoRi.R831_0.6-250mu.ciatable.petitRADTRANS.h5'... Done.
#  Loading CIA opacities for H2-He from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--He/H2--He-NatAbund/H2--He-NatAbund__BoRi.DeltaWavenumber2_0.5-500mu.ciatable.petitRADTRANS.h5'... Done.
#  Successfully loaded all CIA opacities
# Successfully loaded all opacities

# %%
opacities = plot_radtrans_opacities(
    atmosphere,
    atmosphere.line_species,
    temperature=442,
    pressure_bar=1,
    return_opacities=True
)

colors = ['blue', 'orange', 'green', 'purple']
i=0
for species in opacities.keys():
    plt.plot(opacities[species][0], opacities[species][1], label=species,
             color=colors[i]
            )
    i+=1

plt.yscale('log')
plt.xlim([1,5])
plt.ylim([1e-10,1e10])
plt.ylabel('Opacity (cm$^2$ g$^{-1}$)')
plt.xlabel('Wavelength (micron)')
plt.legend()
plt.show()

# %%
# retrieval.get_reduced_chi2_from_model(wavelength, model, verbose=True, show_chi2=True)

x0, y0 = retrieval.get_best_fit_model(np.array([value for item, value in retrieval.get_best_fit_parameters().items()]), parameters_read)
x1, y1 = retrieval.calculate_forward_model()["K2-18b_NIRISS"]
x2, y2 = retrieval.calculate_forward_model()["K2-18b_NIRSPEC"]
plt.plot(x0, y0, label="Best fit model", alpha=0.4)
plt.plot(x1, y1, label="NIRISS spectra model", alpha=0.4)
plt.plot(x2, y2, label="NIRSPEC spectra model", alpha=0.4)
plt.legend()
plt.show()
# Out:
# Loading Radtrans opacities...
#  Loading line opacities of species 'CH4' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CH4/12C-1H4/12C-1H4__YT34to10.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'CO2' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/CO2/12C-16O2/12C-16O2__UCL-4000.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'H2O' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/H2O/1H2-16O/1H2-16O__POKAZATEL.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Loading line opacities of species 'NH3' from file '/home/juan/petitRADTRANS/input_data/opacities/lines/correlated_k/NH3/14N-1H3/14N-1H3__CoYuTe.R1000_0.3-50mu.ktable.petitRADTRANS.h5'... Done.
#  Successfully loaded all line opacities
#  Loading CIA opacities for H2-H2 from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--H2/H2--H2-NatAbund/H2--H2-NatAbund__BoRi.R831_0.6-250mu.ciatable.petitRADTRANS.h5'... Done.
#  Loading CIA opacities for H2-He from file '/home/juan/petitRADTRANS/input_data/opacities/continuum/collision_induced_absorptions/H2--He/H2--He-NatAbund/H2--He-NatAbund__BoRi.DeltaWavenumber2_0.5-500mu.ciatable.petitRADTRANS.h5'... Done.
#  Successfully loaded all CIA opacities
# Successfully loaded all opacities
# Calculating model function for data 'K2-18b_NIRISS'...
# Calculating model function for data 'K2-18b_NIRSPEC'...
# Calculating model function for data 'K2-18b_NIRISS'...
# Calculating model function for data 'K2-18b_NIRSPEC'...
